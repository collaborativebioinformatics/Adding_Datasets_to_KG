# %%
import boto3
from mcp import stdio_client, StdioServerParameters
from strands import Agent
from strands.tools.mcp import MCPClient
import os

# Set global profile name variable that can be used by boto3 and use_aws tool
profile_name = "shared-a"

# Set AWS_PROFILE environment variable globally for all boto3 sessions
os.environ["AWS_PROFILE"] = profile_name
os.environ["AWS_DEFAULT_REGION"] = "us-east-1"

# Set default session profile for boto3 (for legacy code and wrapper tools)
boto3.setup_default_session(profile_name=profile_name)

print("🔧 Setting up MCP Neptune connection...")
query_mcp_client = MCPClient(lambda: stdio_client(StdioServerParameters(command="uvx", 
    args=["awslabs.amazon-neptune-mcp-server@latest"],
    env={"NEPTUNE_ENDPOINT": "neptune-db://midas-test.cluster-c7j2zglv4rfb.us-east-1.neptune.amazonaws.com"},
    )))

print("✅ MCP client created successfully!")
print("🔍 Testing connection...")

with query_mcp_client:
    tools = query_mcp_client.list_tools_sync()
    print(f"✅ Found {len(tools)} tools:")
    for i, tool in enumerate(tools):
        print(f"  {i+1}. {tool.tool_name}: {tool.tool_spec.get('description', 'no description')}")
    
    print("\n🤖 Creating agent...")
    # Create an agent with all tools
    agent = Agent(tools=tools, 
        system_prompt="""You are an agent that interacts with an Amazon Neptune database to run graph queries.
        Whenever you write queries you should first fetch the schema to ensure that you understand the correct labels and property names 
        as well as the appropriate casing of those names and values.
        """,
    )
    
    print("✅ Agent created successfully!")
    print("🎯 Ready to query Neptune database!")
# Out:
# client failed to initialize
# Traceback (most recent call last):
#   File "/home/ubuntu/Adding_Datasets_to_KG/.venv/lib/python3.12/site-packages/strands/tools/mcp/mcp_client.py", line 123, in start
#     self._init_future.result(timeout=self._startup_timeout)
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 456, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/home/ubuntu/Adding_Datasets_to_KG/.venv/lib/python3.12/site-packages/strands/tools/mcp/mcp_client.py", line 397, in _async_background_thread
#     async with self._transport_callable() as (read_stream, write_stream, *_):
#   File "/usr/lib/python3.12/contextlib.py", line 210, in __aenter__
#     return await anext(self.gen)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/Adding_Datasets_to_KG/.venv/lib/python3.12/site-packages/mcp/client/stdio/__init__.py", line 124, in stdio_client
#     process = await _create_platform_compatible_process(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/Adding_Datasets_to_KG/.venv/lib/python3.12/site-packages/mcp/client/stdio/__init__.py", line 250, in _create_platform_compatible_process
#     process = await anyio.open_process(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/Adding_Datasets_to_KG/.venv/lib/python3.12/site-packages/anyio/_core/_subprocesses.py", line 190, in open_process
#     return await get_async_backend().open_process(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/Adding_Datasets_to_KG/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py", line 2588, in open_process
#     process = await asyncio.create_subprocess_exec(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/asyncio/subprocess.py", line 224, in create_subprocess_exec
#     transport, protocol = await loop.subprocess_exec(
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/asyncio/base_events.py", line 1744, in subprocess_exec
#     transport = await self._make_subprocess_transport(
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/asyncio/unix_events.py", line 211, in _make_subprocess_transport
#     transp = _UnixSubprocessTransport(self, protocol, args, shell,
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/asyncio/base_subprocess.py", line 36, in __init__
#     self._start(args=args, shell=shell, stdin=stdin, stdout=stdout,
#   File "/usr/lib/python3.12/asyncio/unix_events.py", line 820, in _start
#     self._proc = subprocess.Popen(
#                  ^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/usr/lib/python3.12/subprocess.py", line 1955, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'uvx'
# 🔧 Setting up MCP Neptune connection...
# ✅ MCP client created successfully!
# 🔍 Testing connection...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/Adding_Datasets_to_KG/.venv/lib/python3.12/site-packages/strands/tools/mcp/mcp_client.py:123, in MCPClient.start(self)
#     121 try:
#     122     # Blocking main thread until session is initialized in other thread or if the thread stops
# --> 123     self._init_future.result(timeout=self._startup_timeout)
#     124     self._log_debug_with_thread("the client initialization was successful")
#
# File /usr/lib/python3.12/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#
# File /usr/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File ~/Adding_Datasets_to_KG/.venv/lib/python3.12/site-packages/strands/tools/mcp/mcp_client.py:397, in MCPClient._async_background_thread(self)
#     396 try:
# --> 397     async with self._transport_callable() as (read_stream, write_stream, *_):
#     398         self._log_debug_with_thread("transport connection established")
#
# File /usr/lib/python3.12/contextlib.py:210, in _AsyncGeneratorContextManager.__aenter__(self)
#     209 try:
# --> 210     return await anext(self.gen)
#     211 except StopAsyncIteration:
#
# File ~/Adding_Datasets_to_KG/.venv/lib/python3.12/site-packages/mcp/client/stdio/__init__.py:124, in stdio_client(server, errlog)
#     123     # Open process with stderr piped for capture
# --> 124     process = await _create_platform_compatible_process(
#     125         command=command,
#     126         args=server.args,
#     127         env=({**get_default_environment(), **server.env} if server.env is not None else get_default_environment()),
#     128         errlog=errlog,
#     129         cwd=server.cwd,
#     130     )
#     131 except OSError:
#     132     # Clean up streams if process creation fails
#
# File ~/Adding_Datasets_to_KG/.venv/lib/python3.12/site-packages/mcp/client/stdio/__init__.py:250, in _create_platform_compatible_process(command, args, env, errlog, cwd)
#     249 else:
# --> 250     process = await anyio.open_process(
#     251         [command, *args],
#     252         env=env,
#     253         stderr=errlog,
#     254         cwd=cwd,
#     255         start_new_session=True,
#     256     )
#     258 return process
#
# File ~/Adding_Datasets_to_KG/.venv/lib/python3.12/site-packages/anyio/_core/_subprocesses.py:190, in open_process(command, stdin, stdout, stderr, cwd, env, startupinfo, creationflags, start_new_session, pass_fds, user, group, extra_groups, umask)
#     188     kwargs["umask"] = umask
# --> 190 return await get_async_backend().open_process(
#     191     command,
#     192     stdin=stdin,
#     193     stdout=stdout,
#     194     stderr=stderr,
#     195     cwd=cwd,
#     196     env=env,
#     197     startupinfo=startupinfo,
#     198     creationflags=creationflags,
#     199     start_new_session=start_new_session,
#     200     pass_fds=pass_fds,
#     201     **kwargs,
#     202 )
#
# File ~/Adding_Datasets_to_KG/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py:2588, in AsyncIOBackend.open_process(cls, command, stdin, stdout, stderr, **kwargs)
#    2587 else:
# -> 2588     process = await asyncio.create_subprocess_exec(
#    2589         *command,
#    2590         stdin=stdin,
#    2591         stdout=stdout,
#    2592         stderr=stderr,
#    2593         **kwargs,
#    2594     )
#    2596 stdin_stream = StreamWriterWrapper(process.stdin) if process.stdin else None
#
# File /usr/lib/python3.12/asyncio/subprocess.py:224, in create_subprocess_exec(program, stdin, stdout, stderr, limit, *args, **kwds)
#     222 protocol_factory = lambda: SubprocessStreamProtocol(limit=limit,
#     223                                                     loop=loop)
# --> 224 transport, protocol = await loop.subprocess_exec(
#     225     protocol_factory,
#     226     program, *args,
#     227     stdin=stdin, stdout=stdout,
#     228     stderr=stderr, **kwds)
#     229 return Process(transport, protocol, loop)
#
# File /usr/lib/python3.12/asyncio/base_events.py:1744, in BaseEventLoop.subprocess_exec(self, protocol_factory, program, stdin, stdout, stderr, universal_newlines, shell, bufsize, encoding, errors, text, *args, **kwargs)
#    1743     self._log_subprocess(debug_log, stdin, stdout, stderr)
# -> 1744 transport = await self._make_subprocess_transport(
#    1745     protocol, popen_args, False, stdin, stdout, stderr,
#    1746     bufsize, **kwargs)
#    1747 if self._debug and debug_log is not None:
#
# File /usr/lib/python3.12/asyncio/unix_events.py:211, in _UnixSelectorEventLoop._make_subprocess_transport(self, protocol, args, shell, stdin, stdout, stderr, bufsize, extra, **kwargs)
#     210 waiter = self.create_future()
# --> 211 transp = _UnixSubprocessTransport(self, protocol, args, shell,
#     212                                 stdin, stdout, stderr, bufsize,
#     213                                 waiter=waiter, extra=extra,
#     214                                 **kwargs)
#     215 watcher.add_child_handler(transp.get_pid(),
#     216                         self._child_watcher_callback, transp)
#
# File /usr/lib/python3.12/asyncio/base_subprocess.py:36, in BaseSubprocessTransport.__init__(self, loop, protocol, args, shell, stdin, stdout, stderr, bufsize, waiter, extra, **kwargs)
#      35 try:
# ---> 36     self._start(args=args, shell=shell, stdin=stdin, stdout=stdout,
#      37                 stderr=stderr, bufsize=bufsize, **kwargs)
#      38 except:
#
# File /usr/lib/python3.12/asyncio/unix_events.py:820, in _UnixSubprocessTransport._start(self, args, shell, stdin, stdout, stderr, bufsize, **kwargs)
#     819 try:
# --> 820     self._proc = subprocess.Popen(
#     821         args, shell=shell, stdin=stdin, stdout=stdout, stderr=stderr,
#     822         universal_newlines=False, bufsize=bufsize, **kwargs)
#     823     if stdin_w is not None:
#
# File /usr/lib/python3.12/subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#
# File /usr/lib/python3.12/subprocess.py:1955, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session, process_group)
#    1954 if err_filename is not None:
# -> 1955     raise child_exception_type(errno_num, err_msg, err_filename)
#    1956 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'uvx'
#
# The above exception was the direct cause of the following exception:
#
# MCPClientInitializationError              Traceback (most recent call last)
# Cell In[2], line 26
#      23 print("✅ MCP client created successfully!")
#      24 print("🔍 Testing connection...")
# ---> 26 with query_mcp_client:
#      27     tools = query_mcp_client.list_tools_sync()
#      28     print(f"✅ Found {len(tools)} tools:")
#
# File ~/Adding_Datasets_to_KG/.venv/lib/python3.12/site-packages/strands/tools/mcp/mcp_client.py:96, in MCPClient.__enter__(self)
#      90 def __enter__(self) -> "MCPClient":
#      91     """Context manager entry point which initializes the MCP server connection.
#      92
#      93     TODO: Refactor to lazy initialization pattern following idiomatic Python.
#      94     Heavy work in __enter__ is non-idiomatic - should move connection logic to first method call instead.
#      95     """
# ---> 96     return self.start()
#
# File ~/Adding_Datasets_to_KG/.venv/lib/python3.12/site-packages/strands/tools/mcp/mcp_client.py:136, in MCPClient.start(self)
#     134     # Pass None for exc_type, exc_val, exc_tb since this isn't a context manager exit
#     135     self.stop(None, None, None)
# --> 136     raise MCPClientInitializationError("the client initialization failed") from e
#     137 return self
#
# MCPClientInitializationError: the client initialization failed

# %%
# Test the agent with a simple query
print("🔍 Testing agent with BCR:ABL query...")
try:
    result = agent("Tell me about BCR:ABL and only from the neptune db and show me cypher query and query result and then provide summary of the query result")
    print("✅ Agent query completed!")
    print("Result:", result)
except Exception as e:
    print(f"❌ Agent query failed: {e}")
    print("This might be due to LLM access issues, but the MCP tools are working!")
# Out:
# client failed to initialize
# Traceback (most recent call last):
#   File "/home/ubuntu/Adding_Datasets_to_KG/.venv/lib/python3.12/site-packages/strands/tools/mcp/mcp_client.py", line 123, in start
#     self._init_future.result(timeout=self._startup_timeout)
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 456, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/home/ubuntu/Adding_Datasets_to_KG/.venv/lib/python3.12/site-packages/strands/tools/mcp/mcp_client.py", line 397, in _async_background_thread
#     async with self._transport_callable() as (read_stream, write_stream, *_):
#   File "/usr/lib/python3.12/contextlib.py", line 210, in __aenter__
#     return await anext(self.gen)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/Adding_Datasets_to_KG/.venv/lib/python3.12/site-packages/mcp/client/stdio/__init__.py", line 124, in stdio_client
#     process = await _create_platform_compatible_process(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/Adding_Datasets_to_KG/.venv/lib/python3.12/site-packages/mcp/client/stdio/__init__.py", line 250, in _create_platform_compatible_process
#     process = await anyio.open_process(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/Adding_Datasets_to_KG/.venv/lib/python3.12/site-packages/anyio/_core/_subprocesses.py", line 190, in open_process
#     return await get_async_backend().open_process(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/Adding_Datasets_to_KG/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py", line 2588, in open_process
#     process = await asyncio.create_subprocess_exec(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/asyncio/subprocess.py", line 224, in create_subprocess_exec
#     transport, protocol = await loop.subprocess_exec(
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/asyncio/base_events.py", line 1744, in subprocess_exec
#     transport = await self._make_subprocess_transport(
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/asyncio/unix_events.py", line 211, in _make_subprocess_transport
#     transp = _UnixSubprocessTransport(self, protocol, args, shell,
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/asyncio/base_subprocess.py", line 36, in __init__
#     self._start(args=args, shell=shell, stdin=stdin, stdout=stdout,
#   File "/usr/lib/python3.12/asyncio/unix_events.py", line 820, in _start
#     self._proc = subprocess.Popen(
#                  ^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/usr/lib/python3.12/subprocess.py", line 1955, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'uvx'
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/Adding_Datasets_to_KG/.venv/lib/python3.12/site-packages/strands/tools/mcp/mcp_client.py:123, in MCPClient.start(self)
#     121 try:
#     122     # Blocking main thread until session is initialized in other thread or if the thread stops
# --> 123     self._init_future.result(timeout=self._startup_timeout)
#     124     self._log_debug_with_thread("the client initialization was successful")
#
# File /usr/lib/python3.12/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#
# File /usr/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File ~/Adding_Datasets_to_KG/.venv/lib/python3.12/site-packages/strands/tools/mcp/mcp_client.py:397, in MCPClient._async_background_thread(self)
#     396 try:
# --> 397     async with self._transport_callable() as (read_stream, write_stream, *_):
#     398         self._log_debug_with_thread("transport connection established")
#
# File /usr/lib/python3.12/contextlib.py:210, in _AsyncGeneratorContextManager.__aenter__(self)
#     209 try:
# --> 210     return await anext(self.gen)
#     211 except StopAsyncIteration:
#
# File ~/Adding_Datasets_to_KG/.venv/lib/python3.12/site-packages/mcp/client/stdio/__init__.py:124, in stdio_client(server, errlog)
#     123     # Open process with stderr piped for capture
# --> 124     process = await _create_platform_compatible_process(
#     125         command=command,
#     126         args=server.args,
#     127         env=({**get_default_environment(), **server.env} if server.env is not None else get_default_environment()),
#     128         errlog=errlog,
#     129         cwd=server.cwd,
#     130     )
#     131 except OSError:
#     132     # Clean up streams if process creation fails
#
# File ~/Adding_Datasets_to_KG/.venv/lib/python3.12/site-packages/mcp/client/stdio/__init__.py:250, in _create_platform_compatible_process(command, args, env, errlog, cwd)
#     249 else:
# --> 250     process = await anyio.open_process(
#     251         [command, *args],
#     252         env=env,
#     253         stderr=errlog,
#     254         cwd=cwd,
#     255         start_new_session=True,
#     256     )
#     258 return process
#
# File ~/Adding_Datasets_to_KG/.venv/lib/python3.12/site-packages/anyio/_core/_subprocesses.py:190, in open_process(command, stdin, stdout, stderr, cwd, env, startupinfo, creationflags, start_new_session, pass_fds, user, group, extra_groups, umask)
#     188     kwargs["umask"] = umask
# --> 190 return await get_async_backend().open_process(
#     191     command,
#     192     stdin=stdin,
#     193     stdout=stdout,
#     194     stderr=stderr,
#     195     cwd=cwd,
#     196     env=env,
#     197     startupinfo=startupinfo,
#     198     creationflags=creationflags,
#     199     start_new_session=start_new_session,
#     200     pass_fds=pass_fds,
#     201     **kwargs,
#     202 )
#
# File ~/Adding_Datasets_to_KG/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py:2588, in AsyncIOBackend.open_process(cls, command, stdin, stdout, stderr, **kwargs)
#    2587 else:
# -> 2588     process = await asyncio.create_subprocess_exec(
#    2589         *command,
#    2590         stdin=stdin,
#    2591         stdout=stdout,
#    2592         stderr=stderr,
#    2593         **kwargs,
#    2594     )
#    2596 stdin_stream = StreamWriterWrapper(process.stdin) if process.stdin else None
#
# File /usr/lib/python3.12/asyncio/subprocess.py:224, in create_subprocess_exec(program, stdin, stdout, stderr, limit, *args, **kwds)
#     222 protocol_factory = lambda: SubprocessStreamProtocol(limit=limit,
#     223                                                     loop=loop)
# --> 224 transport, protocol = await loop.subprocess_exec(
#     225     protocol_factory,
#     226     program, *args,
#     227     stdin=stdin, stdout=stdout,
#     228     stderr=stderr, **kwds)
#     229 return Process(transport, protocol, loop)
#
# File /usr/lib/python3.12/asyncio/base_events.py:1744, in BaseEventLoop.subprocess_exec(self, protocol_factory, program, stdin, stdout, stderr, universal_newlines, shell, bufsize, encoding, errors, text, *args, **kwargs)
#    1743     self._log_subprocess(debug_log, stdin, stdout, stderr)
# -> 1744 transport = await self._make_subprocess_transport(
#    1745     protocol, popen_args, False, stdin, stdout, stderr,
#    1746     bufsize, **kwargs)
#    1747 if self._debug and debug_log is not None:
#
# File /usr/lib/python3.12/asyncio/unix_events.py:211, in _UnixSelectorEventLoop._make_subprocess_transport(self, protocol, args, shell, stdin, stdout, stderr, bufsize, extra, **kwargs)
#     210 waiter = self.create_future()
# --> 211 transp = _UnixSubprocessTransport(self, protocol, args, shell,
#     212                                 stdin, stdout, stderr, bufsize,
#     213                                 waiter=waiter, extra=extra,
#     214                                 **kwargs)
#     215 watcher.add_child_handler(transp.get_pid(),
#     216                         self._child_watcher_callback, transp)
#
# File /usr/lib/python3.12/asyncio/base_subprocess.py:36, in BaseSubprocessTransport.__init__(self, loop, protocol, args, shell, stdin, stdout, stderr, bufsize, waiter, extra, **kwargs)
#      35 try:
# ---> 36     self._start(args=args, shell=shell, stdin=stdin, stdout=stdout,
#      37                 stderr=stderr, bufsize=bufsize, **kwargs)
#      38 except:
#
# File /usr/lib/python3.12/asyncio/unix_events.py:820, in _UnixSubprocessTransport._start(self, args, shell, stdin, stdout, stderr, bufsize, **kwargs)
#     819 try:
# --> 820     self._proc = subprocess.Popen(
#     821         args, shell=shell, stdin=stdin, stdout=stdout, stderr=stderr,
#     822         universal_newlines=False, bufsize=bufsize, **kwargs)
#     823     if stdin_w is not None:
#
# File /usr/lib/python3.12/subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#
# File /usr/lib/python3.12/subprocess.py:1955, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session, process_group)
#    1954 if err_filename is not None:
# -> 1955     raise child_exception_type(errno_num, err_msg, err_filename)
#    1956 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'uvx'
#
# The above exception was the direct cause of the following exception:
#
# MCPClientInitializationError              Traceback (most recent call last)
# Cell In[1], line 18
#      11 boto3.setup_default_session(profile_name=profile_name)
#      13 query_mcp_client = MCPClient(lambda: stdio_client(StdioServerParameters(command='uvx',
#      14     args=['awslabs.amazon-neptune-mcp-server@latest'],
#      15     env={'NEPTUNE_ENDPOINT': 'neptune-db://midas-test.cluster-c7j2zglv4rfb.us-east-1.neptune.amazonaws.com'},
#      16     )))
# ---> 18 with query_mcp_client:
#      19     tools = query_mcp_client.list_tools_sync()
#      20     # Create an agent with all tools
#
# File ~/Adding_Datasets_to_KG/.venv/lib/python3.12/site-packages/strands/tools/mcp/mcp_client.py:96, in MCPClient.__enter__(self)
#      90 def __enter__(self) -> "MCPClient":
#      91     """Context manager entry point which initializes the MCP server connection.
#      92
#      93     TODO: Refactor to lazy initialization pattern following idiomatic Python.
#      94     Heavy work in __enter__ is non-idiomatic - should move connection logic to first method call instead.
#      95     """
# ---> 96     return self.start()
#
# File ~/Adding_Datasets_to_KG/.venv/lib/python3.12/site-packages/strands/tools/mcp/mcp_client.py:136, in MCPClient.start(self)
#     134     # Pass None for exc_type, exc_val, exc_tb since this isn't a context manager exit
#     135     self.stop(None, None, None)
# --> 136     raise MCPClientInitializationError("the client initialization failed") from e
#     137 return self
#
# MCPClientInitializationError: the client initialization failed
